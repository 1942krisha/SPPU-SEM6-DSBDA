# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("income.csv")
df
# Out:
#      Unnamed: 0  age  income
# 0             0   49  946815
# 1             1   55  861096
# 2             2   27  185809
# 3             3   48  791043
# 4             4   23  988453
# ..          ...  ...     ...
# 195         195   38  768508
# 196         196   46  524485
# 197         197   30  251448
# 198         198   51  186821
# 199         199   59  591476
#
# [200 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   age         200 non-null    int64
#  2   income      200 non-null    int64
# dtypes: int64(3)
# memory usage: 4.8 KB

# %%
df.shape
# Out:
# (200, 3)

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# age           0
# income        0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0         age         income
# count  200.000000  200.000000     200.000000
# mean    99.500000   39.370000  499628.450000
# std     57.879185   12.455069  280484.818896
# min      0.000000   18.000000   38983.000000
# 25%     49.750000   28.750000  268601.500000
# 50%     99.500000   40.000000  513547.500000
# 75%    149.250000   50.000000  739039.750000
# max    199.000000   60.000000  991321.000000

# %%
age_ranges = [0, 18, 26, 36, 46, 56, df['age'].max() + 1]
age_labels = ['0-18', '18-25', '26-35', '36-45', '46-55', '56+']
sample = pd.cut(df['age'], bins=age_ranges, labels=age_labels, right=False)
sample
# Out:
# 0      46-55
# 1      46-55
# 2      26-35
# 3      46-55
# 4      18-25
#        ...
# 195    36-45
# 196    46-55
# 197    26-35
# 198    46-55
# 199      56+
# Name: age, Length: 200, dtype: category
# Categories (6, object): ['0-18' < '18-25' < '26-35' < '36-45' < '46-55' < '56+']

# %%
grouped_data = df.groupby(sample)
for group_name, group_data in grouped_data:
    print("Age Group: ", group_name)
    print(group_data)
    print()
# Out:
# Age Group:  0-18
# Empty DataFrame
# Columns: [Unnamed: 0, age, income]
# Index: []
#
# Age Group:  18-25
#      Unnamed: 0  age  income
# 4             4   23  988453
# 6             6   21   49726
# 9             9   25  801821
# 11           11   21  317420
# 13           13   22   45797
# 19           19   20  913832
# 22           22   24  276589
# 25           25   24  563352
# 27           27   25  809613
# 28           28   22  922526
# 31           31   21  306617
# 34           34   18  577483
# 37           37   20  380320
# 38           38   21  930850
# 40           40   19  443902
# 46           46   19   90842
# 47           47   20  438060
# 49           49   19   53193
# 50           50   23  407103
# 69           69   23  604625
# 70           70   21  125989
# 77           77   22  694767
# 79           79   23   78369
# 82           82   24  851512
# 91           91   23  565830
# 92           92   20  118591
# 98           98   22  496306
# ...

# %%
summary_stats = grouped_data['income'].agg(['mean', 'median', 'min', 'max', 'std'])
summary_stats
# Out:
#                 mean    median       min       max            std
# age
# 0-18             NaN       NaN       NaN       NaN            NaN
# 18-25  459608.250000  440981.0   45193.0  988453.0  288659.156205
# 26-35  524999.341463  531716.0  113683.0  978108.0  253198.445002
# 36-45  555566.340909  536867.0  104688.0  991321.0  278005.885392
# 46-55  493168.698113  498426.0   38983.0  991203.0  290851.540759
# 56+    428796.681818  463030.5   54699.0  922925.0  291029.485021

# %%
summary_stats2 = df.groupby(df["age"]).describe()
summary_stats2
# Out:
#     Unnamed: 0                                                              \
#          count        mean        std    min     25%    50%     75%    max
# age
# 18         5.0  109.200000  44.818523   34.0  107.00  123.0  132.00  150.0
# 19         3.0   45.000000   4.582576   40.0   43.00   46.0   47.50   49.0
# 20         5.0   73.400000  61.337590   19.0   37.00   47.0   92.00  172.0
# 21         6.0   46.666667  44.207088    6.0   16.00   34.5   62.00  124.0
# 22         4.0   54.000000  40.091562   13.0   24.25   52.5   82.25   98.0
# 23         8.0   99.750000  62.759746    4.0   64.25   85.0  158.25  182.0
# 24         6.0  107.666667  74.776110   22.0   39.25  119.0  167.25  190.0
# 25         3.0   50.666667  57.291652    9.0   18.00   27.0   71.50  116.0
# 26         3.0  104.333333  38.501082   66.0   85.00  104.0  123.50  143.0
# 27         5.0  105.600000  71.234121    2.0   73.00  118.0  149.00  186.0
# ...

# %%
# Dividing dataset into 2 parts: 18-35, 35-60
young = df[df["age"] <= 35]
young
# Out:
#      Unnamed: 0  age  income
# 2             2   27  185809
# 4             4   23  988453
# 6             6   21   49726
# 7             7   31  823583
# 9             9   25  801821
# ..          ...  ...     ...
# 181         181   33  383315
# 182         182   23  431208
# 186         186   27  978108
# 190         190   24   67924
# 197         197   30  251448
#
# [81 rows x 3 columns]

# %%
old = df[df["age"] > 35]
old
# Out:
#      Unnamed: 0  age  income
# 0             0   49  946815
# 1             1   55  861096
# 3             3   48  791043
# 5             5   50  421806
# 8             8   42  153768
# ..          ...  ...     ...
# 194         194   60  877738
# 195         195   38  768508
# 196         196   46  524485
# 198         198   51  186821
# 199         199   59  591476
#
# [119 rows x 3 columns]
